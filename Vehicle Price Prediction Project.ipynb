# %% [markdown]
# # step1: Load tha data

# %%
import pandas as pd
df=pd.read_csv("auto.txt")
df
# Out:
#      symbolling normalized-losses         make fuel-type aspiration  \
# 0             3                 ?  alfa-romero       gas        std
# 1             3                 ?  alfa-romero       gas        std
# 2             1                 ?  alfa-romero       gas        std
# 3             2               164         audi       gas        std
# 4             2               164         audi       gas        std
# ..          ...               ...          ...       ...        ...
# 200          -1                95        volvo       gas        std
# 201          -1                95        volvo       gas      turbo
# 202          -1                95        volvo       gas        std
# 203          -1                95        volvo    diesel      turbo
# 204          -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %% [markdown]
# # step2:Cleanoing data

# %%
import numpy as np
df=df.replace("?",np.nan)
df.head()
# Out:
#    symbolling normalized-losses         make fuel-type aspiration  \
# 0           3               NaN  alfa-romero       gas        std
# 1           3               NaN  alfa-romero       gas        std
# 2           1               NaN  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
df['price'].describe() # lets see what is the data type cloumns
# Out:
# count       201
# unique      186
# top       16500
# freq          2
# Name: price, dtype: object

# %%
df['bore']
# Out:
# 0      3.47
# 1      3.47
# 2      2.68
# 3      3.19
# 4      3.19
#        ...
# 200    3.78
# 201    3.78
# 202    3.58
# 203    3.01
# 204    3.78
# Name: bore, Length: 205, dtype: object

# %%
df['symbolling'].describe()
# Out:
# count    205.000000
# mean       0.834146
# std        1.245307
# min       -2.000000
# 25%        0.000000
# 50%        1.000000
# 75%        2.000000
# max        3.000000
# Name: symbolling, dtype: float64

# %%
df['horsepower'].describe()
# Out:
# count     203
# unique     59
# top        68
# freq       19
# Name: horsepower, dtype: object

# %%
# whoever data type is object we can convert numeric
df['horsepower']=pd.to_numeric(df['horsepower'],errors='coerce') # coerce means any errors in row that row will dont's stop we can convert remaining rows
df['horsepower'].describe()
# Out:
# count    203.000000
# mean     104.256158
# std       39.714369
# min       48.000000
# 25%       70.000000
# 50%       95.000000
# 75%      116.000000
# max      288.000000
# Name: horsepower, dtype: float64

# %%
df['num-of-cylinders']
# Out:
# 0      four
# 1      four
# 2       six
# 3      four
# 4      five
#        ...
# 200    four
# 201    four
# 202     six
# 203     six
# 204    four
# Name: num-of-cylinders, Length: 205, dtype: object

# %%
df['bore']=pd.to_numeric(df['bore'],errors='coerce') # coerce means any errors in row that row will dont's stop we can convert remaining rows
df['bore'].describe()
# Out:
# count    201.000000
# mean       3.329751
# std        0.273539
# min        2.540000
# 25%        3.150000
# 50%        3.310000
# 75%        3.590000
# max        3.940000
# Name: bore, dtype: float64

# %%
df['price']=pd.to_numeric(df['price'],errors='coerce') # coerce means any errors in row that row will dont's stop we can convert remaining rows
df['price'].describe()
# Out:
# count      201.000000
# mean     13207.129353
# std       7947.066342
# min       5118.000000
# 25%       7775.000000
# 50%      10295.000000
# 75%      16500.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
#lets us removed unvanted columns which are  not useful
df=df.drop('normalized-losses',axis=1)	
df.head()
# Out:
#    symbolling         make fuel-type aspiration num-of-doors   body-style  \
# 0           3  alfa-romero       gas        std          two  convertible
# 1           3  alfa-romero       gas        std          two  convertible
# 2           1  alfa-romero       gas        std          two    hatchback
# 3           2         audi       gas        std         four        sedan
# 4           2         audi       gas        std         four        sedan
#
#   drive-wheels engine-location  wheel-base  length  ...  engine-size  \
# 0          rwd           front        88.6   168.8  ...          130
# 1          rwd           front        88.6   168.8  ...          130
# 2          rwd           front        94.5   171.2  ...          152
# 3          fwd           front        99.8   176.6  ...          109
# 4          4wd           front        99.4   176.6  ...          136
#
#    fuel-system  bore stroke compression-ratio  horsepower peak-rpm  city-mpg  \
# ...

# %%
df.columns
# Out:
# Index(['symbolling', 'make', 'fuel-type', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price'],
#       dtype='object')

# %%
df['make']
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
#           ...
# 200          volvo
# 201          volvo
# 202          volvo
# 203          volvo
# 204          volvo
# Name: make, Length: 205, dtype: object

# %%
cylinders_dict={ 'two':2, 'three':3, 'four':4, 'five':5, 'six':6, 'eight':8, 'twelve':12 } 
df['num-of-cylinders'].replace(cylinders_dict,inplace = True)
df['num-of-cylinders'].head()
# Out:
# C:\Users\Rajeswari\AppData\Local\Temp\ipykernel_24384\1012900922.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['num-of-cylinders'].replace(cylinders_dict,inplace = True)
# ...

# %%
a = {'1bbl':1, '2bbl':2,
       '4bbl':4, 'idi':5, 'mfi':6,
       'mpfi':7, 'spdi':8, 'spfi':9}
df['fuel-system'].replace(a,inplace = True)
b= {'dohc':1, 'dohcv':2, 'l':3,
       'ohc':4, 'ohcf':5, 'ohcv':6,
       'rotor':7}
df['engine-type'].replace(b,inplace = True)
c = {'front':1, 'rear':2} 
df['engine-location'].replace(c,inplace = True)
d = {'4wd':1, 'fwd':2,'rwd':3}
df['drive-wheels'].replace(d,inplace = True)

e= {'alfa-romero':1, 'audi':2, 'bmw':3,
       'chevrolet':4, 'dodge':5, 'honda':6, 'isuzu':7,
       'jaguar':8, 'mazda':9, 'mercedes-benz':10, 'mercury':11,
       'mitsubishi':12, 'nissan':13, 'peugot':14, 'plymouth':15,
       'porsche':16, 'renault':17, 'saab':18, 'subaru':19,
       'toyota':20, 'volkswagen':21, 'volvo':22,
}   
df['make'].replace(e,inplace = True)
f = {'convertible':1,
       'hardtop':2, 'hatchback':3, 'sedan':4,
           'wagon':5}
df['body-style'].replace(f,inplace = True)
g = {'four':4, 'two':2}
df['num-of-doors'].replace(g,inplace = True)

h = {'std':0, 'turbo':1}
df['aspiration'].replace(h,inplace = True)
df.head(10)
# Out:
# C:\Users\Rajeswari\AppData\Local\Temp\ipykernel_24384\1661345332.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['fuel-system'].replace(a,inplace = True)
# C:\Users\Rajeswari\AppData\Local\Temp\ipykernel_24384\1661345332.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
i = {'gas':0, 'diesel':1}
df['fuel-type'].replace(i,inplace = True)
df.head(10)
# Out:
# C:\Users\Rajeswari\AppData\Local\Temp\ipykernel_24384\151070586.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['fuel-type'].replace(i,inplace = True)
# C:\Users\Rajeswari\AppData\Local\Temp\ipykernel_24384\151070586.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
df.isnull()
# Out:
#      symbolling   make  fuel-type  aspiration  num-of-doors  body-style  \
# 0         False  False      False       False         False       False
# 1         False  False      False       False         False       False
# 2         False  False      False       False         False       False
# 3         False  False      False       False         False       False
# 4         False  False      False       False         False       False
# ..          ...    ...        ...         ...           ...         ...
# 200       False  False      False       False         False       False
# 201       False  False      False       False         False       False
# 202       False  False      False       False         False       False
# 203       False  False      False       False         False       False
# 204       False  False      False       False         False       False
#
#      drive-wheels  engine-location  wheel-base  length  ...  engine-size  \
# ...

# %%
df.isna().sum()
# Out:
# symbolling           0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
df.drop('horsepower',axis=1,inplace=True)
df.drop('curb-weight',axis=1,inplace=True)
df.drop('peak-rpm',axis=1,inplace=True)
#df.drop('length',axis=1,inplace=True)

# %%
df=df.dropna()

# %% [markdown]
# # step3:train split test

# %%
from sklearn.model_selection import train_test_split

x=df.drop('price',axis=1)
y=df['price']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# # step4:train the model

# %%
from sklearn.linear_model import LinearRegression
linear_model=LinearRegression()
linear_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
linear_model.score(x_train,y_train)
# Out:
# 0.8977925747050541

# %%
linear_model.coef_
# Out:
# array([  -667.83607138,   -201.03840036, -11877.75594957,   3267.45664655,
#          -341.88511643,   -275.67970494,    534.24818935,  12457.43964247,
#           -27.57274928,     13.49191389,    735.2578018 ,    331.25941981,
#          -633.39734035,    167.85881525,    149.24314962,    266.08507362,
#         -3020.67818985,  -4381.08882035,    866.25626477,   -280.79536587,
#           314.52728571])

# %%
predictors=x_train.columns # see the weight associated with perticuler feature
coef=pd.Series(linear_model.coef_, predictors).sort_values()
print(coef)
# Out:
# fuel-type           -11877.755950
# stroke               -4381.088820
# bore                 -3020.678190
# symbolling            -667.836071
# engine-type           -633.397340
# num-of-doors          -341.885116
# city-mpg              -280.795366
# body-style            -275.679705
# make                  -201.038400
# wheel-base             -27.572749
# length                  13.491914
# engine-size            149.243150
# num-of-cylinders       167.858815
# fuel-system            266.085074
# highway-mpg            314.527286
# height                 331.259420
# drive-wheels           534.248189
# width                  735.257802
# compression-ratio      866.256265
# aspiration            3267.456647
# engine-location      12457.439642
# dtype: float64

# %% [markdown]
# # step5:test algorithm

# %%
#lets predict using linear regression model
y_predict =linear_model.predict(x_test)

# %%
# %pylab inline
pylab.rcParams['figure.figsize']=(15,6)
plt.plot(y_predict,label='predicted')
plt.plot(y_test.values,label='Actual')
plt.ylabel('price')
plt.legend()
plt.show()
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\Rajeswari\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\magics\pylab.py:166: UserWarning: pylab import has clobbered these variables: ['f', 'e']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
# how will our regerssion model on our test data
score=linear_model.score(x_test,y_test)
score
# Out:
# 0.8409940243694649

# %% [markdown]
# # step6:find the error

# %% [markdown]
# ### mean squred error.... this will tell us how much error is there in the given output

# %%
from sklearn.metrics import mean_squared_error
linear_model_mse=mean_squared_error(y_predict,y_test)
linear_model_mse
# Out:
# 9848274.421919683

# %%
import math
math.sqrt(linear_model_mse)
# Out:
# 3138.196045807158

# %%
y_predict=linear_model.predict(x_test)
score=linear_model.score(x_test,y_test)
print("accuracy of lasso model is...",score)
linear_model_mse=mean_squared_error(y_predict,y_test)
print("error of lasso model is...",math.sqrt(linear_model_mse))
# Out:
# accuracy of lasso model is... 0.8409940243694649
# error of lasso model is... 3138.196045807158

# %% [markdown]
# # step7: imporivse ,lets us test for next algorithm

# %%
from sklearn.linear_model import Lasso
lasso_model=Lasso(alpha=0.5)
lasso_model.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.5)

# %%
coef=pd.Series(lasso_model.coef_,predictors).sort_values()
print(coef)
# Out:
# fuel-type           -11276.475307
# stroke               -4339.482678
# bore                 -2900.705799
# symbolling            -664.215329
# engine-type           -637.747598
# num-of-doors          -336.587744
# body-style            -280.001734
# city-mpg              -278.417707
# make                  -200.698903
# wheel-base             -28.511348
# length                  13.367697
# engine-size            147.506614
# num-of-cylinders       225.087723
# fuel-system            265.510772
# highway-mpg            313.267707
# height                 331.743139
# drive-wheels           542.464925
# width                  737.742713
# compression-ratio      822.657991
# aspiration            3218.009412
# engine-location      12438.516845
# dtype: float64

# %%
y_predict=lasso_model.predict(x_test)
score=lasso_model.score(x_test,y_test)
print("accuracy of lasso model is...",score)
lasso_model_mse=mean_squared_error(y_predict,y_test)
print("error of lasso model is...",math.sqrt(lasso_model_mse))
# Out:
# accuracy of lasso model is... 0.8424294881441163
# error of lasso model is... 3123.998529530375

# %% [markdown]
# ## conclusion of lasso algorithm is 84 % and error is 3123

# %%
from sklearn.linear_model import Ridge
ridge_model=Ridge(alpha=0.5)
ridge_model.fit(x_train,y_train)
y_predict=ridge_model.predict(x_test)
score=ridge_model.score(x_test,y_test)
print("accuracy of lasso model is...",score)
ridge_model_mse=mean_squared_error(y_predict,y_test)
print("error of lasso model is...",math.sqrt(ridge_model_mse))
# Out:
# accuracy of lasso model is... 0.8501346473276964
# error of lasso model is... 3046.6598401154793

# %% [markdown]
# ## conclusion for ridge LGORITHM ACCURACY 85% AND ERROR IS 3046 DOLLERS
# ## final conclusion iam recommended ridge algorithm for vehicle price prediction
